# %% [markdown]
# # IFS - Data Science - Alex Paulo
# ### Regression
# ### Dataset from https://www.kaggle.com/datasets/vikrishnan/boston-house-prices

# %% [markdown]
# ### O que é Regressão?

# %%
from IPython.display import display, Image

display(Image(filename='./humidity_precipitation.png'))

# %% [markdown]
# Por meio de um gráfico de dispersão (scatter) é possível perceber a inquestionável relação entre humidade e precipitação! Ambientes com maior umidade relativa (referenciada como umidade atmosférica) apresentam maior precipitação! Como uma sauna. Maior humidade (ambientes próximos a rios e ao mar) significa menor amplitude térmica! Por isso, no deserto, é possível mensurar 0 graus à noite... e 50 graus durante o dia!

# %% [markdown]
# | Aluno           | Horas de Estudo | Nota  |
# | --------------- | --------------- | ----- |
# | José            | 20              | 9,5   |
# | Maria           | 12              | 2,5   |
# | Pedro           | 14              | 3,6   |
# | Marcelo         | 15              | 6,7   |
# | Roberto         | 15              | 5,2   |
# | Marta           | 9               | 1     |
# | Ricardo         | 5               | 0     |
# | Kaio            | 4               | 1,5   |
# | Renato          | 8               | 2     |
# | Francisco       | 13              | 3     |
# | Vagner          | 14              | 3,5   |
# | Henrique        | 15              | 4,5   |
# | Vania           | 19              | 8,5   |
# | Camila          | 18              | 7,5   |
# | Priscila        | 12              | 5     |
# | Jorge           | 11              | 4     |
# | Rafael          | 10              | 3     |
# | Rodrigo         | 15              | 5     |
# | Lucas           | 17              | 6,5   |
# | Bruno           | 20              | 10    |

# %%
display(Image(filename='./nota_x_horas_estudo.png'))

# %% [markdown]
# ### Exercício
#
# ##### 1) Importe os dados da base gratuita existente em https://www.kaggle.com/datasets/vikrishnan/boston-house-prices. Baixe o arquivo, estude seu formato, e organize um csv que deverá ser importado utilizando o método read_csv da biblioteca pandas.
#
# ##### 2) Faça uma análise exploratória dos dados carregados no DataFrame adquirido com a invocação do método read_csv, realizada na questão anterior.
#
# ##### 3) Faça um split nos dados do DataFrame, com o objetivo de alocar o campo que a regressão almeja representar "MEDV" (Valor de Mercado) em uma variável intitulada y. E o campo que deverá ser utilizado como subsídio para a regressão "RM" (Média de quartos por habilitação) em uma variável intitulada X.
#
# ##### 4) Monte um gráfico para estudar a hipótese de correlação entre as variáveis MEDV e RM.
#
# ##### 5) Se a correlação for perceptível*, utilize a classe LinearRegression, do pacote sklearn.linear_model, para configurar uma regressão que seja útil para mensurar um estimativa de preço proveniente da correlação identificada.
#
# *: Existem coeficientes de correlação na estatística, para mensurar tais correlações. Sobretudo, neste exercício específico, tente inferir a correlação por meio do gráfico utilizado como resposta para a questão 4.
#
# ##### 6) Acrescente, ao gráfico criado na quetão 4, uma linha representando a mensuração de valor em função da média de número de quartos.
